# %% [markdown]
# <a href="https://colab.research.google.com/github/Farrukh776/flyrank-ai/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Farrukh776/flyrank-ai/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
print("I'm picking Lane 2: Refresh / Content Opportunity Scoring. The starter pipeline I ran in Week 1 already showed a learned ranking (random forest, Precision@50 = 0.740) beating a hand-written rule (Precision@50 = 0.240) at prioritizing which pages to review — a ~3x improvement. That gap tells me there's real signal in this data beyond what a simple rule captures, which is exactly what this lane investigates further.")
# Out:
# I'm picking Lane 2: Refresh / Content Opportunity Scoring. The starter pipeline I ran in Week 1 already showed a learned ranking (random forest, Precision@50 = 0.740) beating a hand-written rule (Precision@50 = 0.240) at prioritizing which pages to review — a ~3x improvement. That gap tells me there's real signal in this data beyond what a simple rule captures, which is exactly what this lane investigates further.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
"Decision improved: which declining/at-risk page a content editor should review and refresh first, given limited review capacity.
Who acts: a content editor or SEO strategist, who picks pages off the ranked queue and rewrites/updates/expands them.
Cost of a wrong call: a false positive wastes editor hours reviewing a page that wasn't actually a priority; a false negative means a genuinely declining page gets missed and keeps losing traffic unnoticed.
Why ML/data helps: the pattern (which combination of staleness, visibility, position, and engagement predicts real decline) is too tangled and multi-signal for a hand-written if/else rule to capture well — which is exactly what the 3x precision gap between the baseline rule and the random forest already demonstrated.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os, subprocess, sys

# If we're in Colab and haven't cloned the repo yet, clone it
if "google.colab" in sys.modules and not os.path.exists("flyrank-ai"):
    subprocess.run(["git", "clone", "https://github.com/Farrukh776/flyrank-ai.git"], check=True)
    os.chdir("flyrank-ai")
elif os.path.exists("flyrank-ai"):
    os.chdir("flyrank-ai")

print("Working directory:", os.getcwd())
print("File exists:", os.path.exists("data/raw/content_refresh_anonymized.csv"))

import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print(f"Rows: {len(df):,}")
print(f"Unique clients: {df['client_id'].nunique()}")
print(f"Share of pages currently trending down: {(df['trend_direction'] == 'down').mean():.1%}")

# Baseline rule vs random forest, from the pipeline you already ran
print("Baseline rule Precision@50: 0.240")
print("Random forest Precision@50: 0.740")
# Out:
# Working directory: /content/flyrank-ai/flyrank-ai
# File exists: True
# Rows: 30,000
# Unique clients: 32
# Share of pages currently trending down: 54.2%
# Baseline rule Precision@50: 0.240
# Random forest Precision@50: 0.740

# %% [markdown]
# With 30,000 pages across 32 clients and over half currently declining, there's real volume and real signal here, and the pipeline already shows a model beating a hand rule by 3x, which is the gap this lane will dig into further

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
print("This work will produce observed, directional, decision-support output — a ranked queue that helps a human prioritize review, with reason codes they can inspect. It will not claim to have reverse-engineered Google's ranking algorithm, and it will not claim that refreshing a page causes recovery — that would require a controlled experiment, not just this data.")
# Out:
# This work will produce observed, directional, decision-support output — a ranked queue that helps a human prioritize review, with reason codes they can inspect. It will not claim to have reverse-engineered Google's ranking algorithm, and it will not claim that refreshing a page causes recovery — that would require a controlled experiment, not just this data.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ x] Every section above is filled — markdown thinking AND the code that backs it
# - [ x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ x] No client names, URLs, or private queries anywhere
# - [ x] My claims use careful words: observed, measured, directional, decision-support
# - [ x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
